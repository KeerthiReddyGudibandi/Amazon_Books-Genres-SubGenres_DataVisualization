# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Books_df.csv')
df
# Out:
#       Unnamed: 0                                              Title  \
# 0              0              The Complete Novel of Sherlock Holmes
# 1              1  Black Holes (L) : The Reith Lectures [Paperbac...
# 2              2                                    The Kite Runner
# 3              3  Greenlights: Raucous stories and outlaw wisdom...
# 4              4  The Science of Storytelling: Why Stories Make ...
# ...          ...                                                ...
# 7923        7923  Insight Guides Poland (Travel Guide with Free ...
# 7924        7924              Lonely Planet India 19 (Travel Guide)
# 7925        7925  Eyewitness Travel Phrase Book French (EW Trave...
# 7926        7926             Lonely Planet Australia (Travel Guide)
# 7927        7927  Political Map of India Latest Map of India Wit...
#
#                     Author                Main Genre                Sub Genre  \
# ...

# %%
df.isnull()
# Out:
#       Unnamed: 0  Title  Author  Main Genre  Sub Genre   Type  Price  Rating  \
# 0          False  False   False       False      False  False  False   False
# 1          False  False   False       False      False  False  False   False
# 2          False  False   False       False      False  False  False   False
# 3          False  False   False       False      False  False  False   False
# 4          False  False   False       False      False  False  False   False
# ...          ...    ...     ...         ...        ...    ...    ...     ...
# 7923       False  False   False       False      False  False  False   False
# 7924       False  False   False       False      False  False  False   False
# 7925       False  False   False       False      False  False  False   False
# 7926       False  False   False       False      False  False  False   False
# 7927       False  False   False       False      False  False  False   False
#
#       No. of People rated   URLs
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Title                   0
# Author                 21
# Main Genre              0
# Sub Genre               0
# Type                    0
# Price                   0
# Rating                  0
# No. of People rated     0
# URLs                    0
# dtype: int64

# %%
df['Author'].fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Title                  0
# Author                 0
# Main Genre             0
# Sub Genre              0
# Type                   0
# Price                  0
# Rating                 0
# No. of People rated    0
# URLs                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# Title                   object
# Author                  object
# Main Genre              object
# Sub Genre               object
# Type                    object
# Price                   object
# Rating                 float64
# No. of People rated    float64
# URLs                    object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     7
# float64    2
# int64      1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7928 entries, 0 to 7927
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           7928 non-null   int64
#  1   Title                7928 non-null   object
#  2   Author               7928 non-null   object
#  3   Main Genre           7928 non-null   object
#  4   Sub Genre            7928 non-null   object
#  5   Type                 7928 non-null   object
#  6   Price                7928 non-null   object
#  7   Rating               7928 non-null   float64
#  8   No. of People rated  7928 non-null   float64
#  9   URLs                 7928 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 619.5+ KB

# %%
df.head(20)
# Out:
#     Unnamed: 0                                              Title  \
# 0            0              The Complete Novel of Sherlock Holmes
# 1            1  Black Holes (L) : The Reith Lectures [Paperbac...
# 2            2                                    The Kite Runner
# 3            3  Greenlights: Raucous stories and outlaw wisdom...
# 4            4  The Science of Storytelling: Why Stories Make ...
# 5            5  Fantastic Beasts and Where to Find Them: The O...
# 6            6  Fantastic Beasts: The Crimes of Grindelwald - ...
# 7            7  Desperately Seeking Shah Rukh : India's Lonely...
# 8            8  Save the Cat!: The Last Book on Screenwriting ...
# 9            9                                         Screenplay
# 10          10                                            One Day
# 11          11                   SACH KAHUN TOH: AN AUTOBIOGRAPHY
# 12          12                          A PRINCESS REMEMBERS (PB)
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df['Author'].isnull().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7923    False
# 7924    False
# 7925    False
# 7926    False
# 7927    False
# Length: 7928, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             Rating  No. of People rated
# count  7928.000000          7928.000000
# mean      4.260797          6479.312941
# std       0.910659         22082.884343
# min       0.000000             0.000000
# 25%       4.300000            63.000000
# 50%       4.500000           499.000000
# 75%       4.600000          2905.250000
# max       5.000000        500119.000000

# %%
df['Price'] = df['Price'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7928 entries, 0 to 7927
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                7928 non-null   object
#  1   Author               7928 non-null   object
#  2   Main Genre           7928 non-null   object
#  3   Sub Genre            7928 non-null   object
#  4   Type                 7928 non-null   object
#  5   Price                7928 non-null   float64
#  6   Rating               7928 non-null   float64
#  7   No. of People rated  7928 non-null   float64
#  8   URLs                 7928 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 557.6+ KB

# %%
Q1=df['Price'].quantile(0.25)
Q3=df['Price'].quantile(0.75)
IQR=Q3-Q1
lowoutlier=Q1-1.5*IQR
highoutlier=Q3+1.5*IQR
totaloutlier=((df['Price']<lowoutlier)|(df['Price']>highoutlier)).sum()
print('Total no of Outliers: ',totaloutlier)
print('Low Outlier: ',lowoutlier)
print('High Outlier: ',highoutlier)


# Printing the Total No of Outliers
# Printing the Low Outlier
# printing the High Outlier
# Out:
# Total no of Outliers:  810
# Low Outlier:  -211.51
# High Outlier:  869.8499999999999

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Rating'],bins=50)

# This Histogram is plotted for the Count of Ratings from 0 to 5 star

# There are most number of books present in the rating range of 4 to 5
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Rating', y='Main Genre', data=df, orient='h')
plt.title('Distribution of Ratings by Genre')
plt.xlabel('Rating')
plt.ylabel('Genre')
plt.show()

# This Box Plot is plotted to Find the Distribution of Genres among all the Star ratings
# We can observe that the 'LAW' Genre has books among all the ratings

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Main Genre',data=df)
plt.xticks(rotation=80)
plt.show()

# Number of books present in each Main Genre

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Type',data=df)
plt.xticks(rotation=80)
plt.show()

# This barplot is plotted to find the count of the type of the books
# We can find out that The most number of books are in the type 'paperback' and 'Kindle'

# %%
df.value_counts('Type')
# Out:
# Type
# Paperback                          4200
# Kindle Edition                     2347
# Hardcover                           787
# Audible Audiobook                   199
# Board book                          181
# Perfect Paperback                    45
# Product Bundle                       44
# Unknown Binding                      24
# Mass Market Paperback                17
# Sheet music                          16
# Spiral-bound                         12
# Cards                                 9
# Flexibound                            9
# Wall Chart                            7
# Kindle Edition with Audio/Video       4
# Staple Bound                          4
# Textbook Binding                      3
# Poster                                3
# Map                                   2
# Single Issue Magazine                 2
# Library Binding                       1
# Gift                                  1
# Stationery                            1
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Price', y='Main Genre', data=df, estimator=np.mean)
plt.title('Average Price by Genre')
plt.xlabel('Average Price')
plt.ylabel('Genre')
plt.show()

# Here the Barplot is plotted between 'Main Genre' and 'Price'
# Here we have taken estimation on the bases of Mean of prices
# This Bar Plot tells the average price of each 'Main Genre'
# From the BarPlot we can find that The books belong to 'Medicine & Health Sciences' are relatively expensive than the other Genres.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Rating', y='Main Genre', data=df, estimator=np.mean)
plt.title('Average Rating by Genre')
plt.xlabel('Average Rating')
plt.ylabel('Genre')
plt.show()

# This Bar Plot is plotted to find Averag Rating by Genre
# From this Bar Plot we can find out that Law Books have Less Average Rating among all the other books

# %%
#Ranking the Authors by 'Rating' and 'No.of People rated'
highly_rated_books = df[df['Rating']>=4.5]
ratings_threshold = highly_rated_books['No. of People rated'].quantile(0.25)
hidden_gems = highly_rated_books[highly_rated_books['No. of People rated']<=ratings_threshold]
hidden_gems_sorted = hidden_gems.sort_values(by=['Rating','Price'],ascending=[False,True])
hidden_gems_sorted.head(10)
# Out:
#                                                   Title  \
# 4947  Struggle To Spark: 5 Effective Ways To Save Yo...
# 2941                               IC-38 Life Insurance
# 1332  Super Froggy Begins – A Fun-Filled Early Reade...
# 3046                    Metamorphosis (Pocket Classics)
# 6972      Mountain Biking Mastery: A Beginner’s Gateway
# 2627  SPEAK WITH YOUR EYES: Understanding Facial Exp...
# 5011  SELF MANAGEMENT: SKILL REQUIRED FOR SELF-MANAG...
# 2920  Arihant NTA CUET UG 15 Mock Test For Section 2...
# 2937  Arihant NTA CUET UG 15 Mock Test For Section 2...
# 7661  Sudoku Puzzles - Book 4 - Brain Activity Book ...
#
#                                  Author                         Main Genre  \
# 4947                     ANAMIKA MISHRA                            Romance
# 2941              Mohinder Singh Kamboj                   Exam Preparation
# 1332                     Elisa Anderson                   Children's Books
# ...

# %%
#Printing Top 10 Best rated Authors,Most Expensive Authors,Top Rated Authors
min_ratings_threshold = 1000
author_stats = df.groupby('Author').agg({
    'Rating':'mean',
    'Price':'mean',
    'No. of People rated':['sum','mean']
}).reset_index()
author_stats.columns = ['Author','Avg Rating','Avg Price','Total Ratings','Avg Ratings per Book']
best_rated_authors = author_stats[author_stats['Avg Ratings per Book'] > min_ratings_threshold].sort_values(by='Avg Rating', ascending=False).head(10)
most_expensive_authors = author_stats.sort_values(by='Avg Price', ascending=False).head(10)
most_rated_authors = author_stats.sort_values(by='Total Ratings', ascending=False).head(10)
best_rated_authors,most_expensive_authors,most_rated_authors
# Out:
# (                       Author  Avg Rating  Avg Price  Total Ratings  \
#  1644              Joy Alukkas         5.0     464.88         1274.0
#  2175  Michael Dante DiMartino         4.9    2148.00         1615.0
#  513            Bret Contreras         4.9    4119.00         5120.0
#  1174             Frank Thomas         4.9    4079.00         1903.0
#  3379            Trent Shelton         4.9     567.00         1070.0
#  3306             Tatsuya Endo         4.9     492.00         5053.0
#  947        Dr. Aaron Horschig         4.9    4594.00         3475.0
#  727            Cori Doerrfeld         4.9     389.00        12927.0
#  1822         L. M. Montgomery         4.9     442.69         1990.0
#  1908       Little Tiger Press         4.9     226.00        71361.0
#
#        Avg Ratings per Book
#  1644                1274.0
#  2175                1615.0
#  513                 5120.0
#  1174                1903.0
#  3379                1070.0
#  3306                5053.0
# ...

# %%
#Plotting Bar plots for Most Expensive Authors and Top rated Authors
plt.figure(figsize=(18,14),dpi=200)

plt.subplot(3,1,2)
sns.barplot(x='Avg Price', y='Author', data=most_expensive_authors)
plt.title('Top 10 most Expnsive Authors')
plt.xlabel('Average Price (₹)')
plt.ylabel('Author')
plt.subplot(3,1,3)
sns.barplot(x='Total Ratings',y='Author',data=most_rated_authors)
plt.title('Top 10 Most Rated Authors')
plt.xlabel('Total Ratings')
plt.ylabel('Author')
plt.tight_layout()
plt.show()
# 2 Bar Plots are plotted
# First Barplot is for Most Expensive Authors, 'Sigeru Omantu' is the most Expensive Author
# Second Barplot is for Most Rated Authors, 'J K.Rowling' is the Most Rated Author

# %%
#Plotting a Scatter Plot between 'Price' and 'Rating of Books'
plt.figure(figsize=(12,8),dpi=200)
sns.scatterplot(x='Price',y='Rating',data=df,alpha=0.5)
plt.title('Price vs. Rating of Books')
plt.xlabel('Price (₹)')
plt.ylabel('Rating')
plt.xscale('log')
plt.grid(True,which="both",ls="--")
plt.show()

# %%
#Pair Plot between 3 Variables 'Price', 'Rating', 'No of People Rated'
sns.pairplot(df)

# %%
print(df['Price'].sum)
print(df['Price'].mean)
print(df['Price'].median)
print(df['Price'].std())
# Out:
# <bound method Series.sum of 0        169.00
# 1         99.00
# 2        175.75
# 3        389.00
# 4        348.16
#          ...
# 7923    1326.00
# 7924     850.00
# 7925     307.00
# 7926    1814.50
# 7927      99.00
# Name: Price, Length: 7928, dtype: float64>
# <bound method Series.mean of 0        169.00
# 1         99.00
# 2        175.75
# 3        389.00
# 4        348.16
#          ...
# 7923    1326.00
# 7924     850.00
# 7925     307.00
# 7926    1814.50
# 7927      99.00
# Name: Price, Length: 7928, dtype: float64>
# <bound method Series.median of 0        169.00
# 1         99.00
# 2        175.75
# 3        389.00
# 4        348.16
#          ...
# 7923    1326.00
# 7924     850.00
# 7925     307.00
# 7926    1814.50
# 7927      99.00
# Name: Price, Length: 7928, dtype: float64>
# 945.9001456729325
